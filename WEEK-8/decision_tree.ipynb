# %% [markdown]
# <a href="https://colab.research.google.com/github/SdMujtaba/2025-26-4123-Syed-Mujtaba--AI-B-DS/blob/main/WEEK-8/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.tree import DecisionTreeClassifier

x = [[1,1],[1,0],[0,1],[0,0]]
y = [0,1,1,0]

model = DecisionTreeClassifier()
model.fit(x,y)

print(model.predict([[0,1]]))
# Out:
# [1]
