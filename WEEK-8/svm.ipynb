# %% [markdown]
# <a href="https://colab.research.google.com/github/SdMujtaba/2025-26-4123-Syed-Mujtaba--AI-B-DS/blob/main/WEEK-8/svm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import svm

x = [[2,2],[4,4],[2,0],[0,2]]
y = [1,1,-1,-1]

model = svm.SVC(kernel='linear')
model.fit(x,y)

print(model.predict([[0,0]]))
# Out:
# [-1]
