# %% [markdown]
# <a href="https://colab.research.google.com/github/SdMujtaba/2025-26-4123-Syed-Mujtaba--AI-B-DS/blob/main/WEEK-8/confusion_matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_curve, auc
import matplotlib.pyplot as plt

y_true = [1, 0, 1, 0, 1, 0, 1, 0]
y_pred = [1, 1, 1, 0, 0, 0, 1, 0]

cm = confusion_matrix(y_true, y_pred)

print("Confusion Matrix:", cm)
print("Precision:", precision_score(y_true, y_pred))
print("Recall:", recall_score(y_true, y_pred))
print("F1:", f1_score(y_true, y_pred))

y_score = [0.9, 0.6, 0.8, 0.3, 0.4, 0.2, 0.85, 0.1]

fpr, tpr, _ = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

print("AUC:", roc_auc)

plt.plot(fpr, tpr)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC Curve")
plt.show()
# Out:
# Confusion Matrix: [[3 1]
#  [1 3]]
# Precision: 0.75
# Recall: 0.75
# F1: 0.75
# AUC: 0.9375
