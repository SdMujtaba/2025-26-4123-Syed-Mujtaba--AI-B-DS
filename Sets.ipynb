# %% [markdown]
# <a href="https://colab.research.google.com/github/SdMujtaba/2025-26-4123-Syed-Mujtaba--AI-B-DS/blob/main/Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Union
A = {1, 2, 3}
B = {3, 4, 5}

print(A.union(B))
# Out:
# {1, 2, 3, 4, 5}

# %%
# creating of set
numbers = {1,2,3,4}
print(numbers)
# Out:
# {1, 2, 3, 4}
