# %% [markdown]
# <a href="https://colab.research.google.com/github/SdMujtaba/2025-26-4123-Syed-Mujtaba--AI-B-DS/blob/main/Operations_using_SQLite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("test.db")
cursor = conn.cursor()

# CREATE TABLE
cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    age INTEGER
)
""")

# CREATE (Insert)
cursor.execute("INSERT INTO users (name, age) VALUES (?, ?)", ("Alice", 25))
conn.commit()

# READ
cursor.execute("SELECT * FROM users")
print("After Insert:", cursor.fetchall())

# UPDATE
cursor.execute("UPDATE users SET age = ? WHERE name = ?", (26, "Alice"))
conn.commit()

cursor.execute("SELECT * FROM users")
print("After Update:", cursor.fetchall())

# DELETE
cursor.execute("DELETE FROM users WHERE name = ?", ("Alice",))
conn.commit()

cursor.execute("SELECT * FROM users")
print("After Delete:", cursor.fetchall())

conn.close()
# Out:
# After Insert: [(1, 'Alice', 25)]
# After Update: [(1, 'Alice', 26)]
# After Delete: []
